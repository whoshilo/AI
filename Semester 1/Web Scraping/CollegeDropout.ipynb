# %% [markdown]
# I would choose Mines because I will make

# %%
from bs4 import BeautifulSoup as BS
import requests
import random
import pandas as pd
import seaborn

# %%
url = "https://api.data.gov/ed/collegescorecard/v1/schools?api_key=HngHm2KTwhlF9Vegmb0MGrTruQuZnHh4fMPxkecw&school.name=Mines"

headers = {
    "accept": "application/json",
    "Authorization": "HngHm2KTwhlF9Vegmb0MGrTruQuZnHh4fMPxkecw"
}
response = requests.get(url, headers=headers)
response = response.json()
response
# Out:
# {'metadata': {'page': 0, 'total': 2, 'per_page': 20},
#  'results': [{'latest': {'school': {'zip': '80401',
#      'city': 'Golden',
#      'name': 'Colorado School of Mines',
#      'alias': 'Mines',
#      'state': 'CO',
#      'locale': 21,
#      'address': '1500 Illinois St',
#      'dolflag': 0,
#      'branches': 1,
#      'men_only': 0,
#      'operating': 1,
#      'ownership': 1,
#      'region_id': 7,
#      'accreditor': 'Higher Learning Commission',
#      'school_url': 'www.mines.edu/',
#      'state_fips': 8,
#      'women_only': 0,
#      'main_campus': 1,
#      'online_only': 0,
#      'endowment': {'end': 322221638, 'begin': 359223868},
#      'carnegie_basic': 15,
#      'faculty_salary': 13173,
#      'ownership_peps': 1,
#      'peps_ownership': 'Public',
#      'accreditor_code': 'NCACHE',
#      'ft_faculty_rate': 0.6555,
#      'carnegie_undergrad': 14,
#      'degree_urbanization': 0,
#      'under_investigation': 0,
# ...

# %%
url = "https://api.data.gov/ed/collegescorecard/v1/schools?api_key=HngHm2KTwhlF9Vegmb0MGrTruQuZnHh4fMPxkecw&school.name=University of Colorado Boulder"

headers = {
    "accept": "application/json",
    "Authorization": "HngHm2KTwhlF9Vegmb0MGrTruQuZnHh4fMPxkecw"
}
response = requests.get(url, headers=headers)
response = response.json()
response
# Out:
# {'metadata': {'page': 0, 'total': 1, 'per_page': 20},
#  'results': [{'latest': {'school': {'zip': '80309-0017',
#      'city': 'Boulder',
#      'name': 'University of Colorado Boulder',
#      'alias': 'U of Colorado|Univ of Colorado|University of Colorado|U of CO|Univ of CO|University of CO|Boulder|CU|CU-Boulder|UCB|CUB|Colorado|Colorado University|U of Colo|Univ of Colo|University of Colo|Colo|Buffs|Buffalos|Buffaloes|CU at Boulder|Golden Buffs|University of Colorado at Boulder',
#      'state': 'CO',
#      'locale': 12,
#      'address': 'Regent Drive at Broadway',
#      'dolflag': 0,
#      'branches': 1,
#      'men_only': 0,
#      'operating': 1,
#      'ownership': 1,
#      'region_id': 7,
#      'accreditor': 'Higher Learning Commission',
#      'school_url': 'www.colorado.edu/',
#      'state_fips': 8,
#      'women_only': 0,
#      'main_campus': 1,
#      'online_only': 0,
#      'endowment': {'end': None, 'begin': None},
#      'carnegie_basic': 15,
# ...

# %%
Mname = pd.DataFrame(response['results'])
Mname.columns
# Out:
# Index(['latest', 'school', 'location', 'id', 'ope6_id', 'ope8_id',
#        'fed_sch_cd'],
#       dtype='object')
