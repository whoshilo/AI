# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_json('games.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50872 entries, 0 to 50871
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app_id          50872 non-null  int64
#  1   title           50872 non-null  object
#  2   date_release    50872 non-null  object
#  3   win             50872 non-null  bool
#  4   mac             50872 non-null  bool
#  5   linux           50872 non-null  bool
#  6   rating          50872 non-null  object
#  7   positive_ratio  50872 non-null  int64
#  8   user_reviews    50872 non-null  int64
#  9   price_final     50872 non-null  float64
#  10  price_original  50872 non-null  float64
#  11  discount        50872 non-null  int64
#  12  steam_deck      50872 non-null  bool
# dtypes: bool(4), float64(2), int64(4), object(3)
# memory usage: 4.1+ MB

# %%
sns.scatterplot(data=df, x="price_original", y="rating")
# Out:
# <Axes: xlabel='price_original', ylabel='rating'>
