# %%
import pandas as pd
import seaborn as sns
import requests

# %% [markdown]
# # 71bd8eaf2a658151e7eee097f968e2c8

# %%
#Now Playing
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MWJkOGVhZjJhNjU4MTUxZTdlZWUwOTdmOTY4ZTJjOCIsIm5iZiI6MTcyNzk3MDM0Mi41MDc4NTksInN1YiI6IjY2ZmViNWMxNzgzMGMxMzAxZTdjOTAwNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.tN9DHyONAM1fq4thObPuh4PqayuNkAUlOGro2ahq3Pg"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response['results'])
now.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg         [878, 28, 12]   912649
# 1  False  /18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg        [27, 53, 9648]  1034541
# 2  False  /v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg      [16, 878, 10751]  1184918
# 3  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [18, 27, 878]   933260
# 4  False  /zViRwl3ySscZnbXZJ2Q9wq3SeUG.jpg  [16, 878, 12, 10751]   698687
#
#   original_language         original_title  \
# 0                en  Venom: The Last Dance
# 1                en            Terrifier 3
# 2                en         The Wild Robot
# 3                en          The Substance
# 4                en       Transformers One
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...    3685.151
# 1  Five years after surviving Art the Clown's Hal...    2813.154
# 2  After a shipwreck, an intelligent robot called...    2050.517
# 3  A fading celebrity decides to use a black mark...    1676.118
# 4  The untold origin story of Optimus Prime and M...    1468.358
#
#                         poster_path release_date                  title  \
# 0  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-22  Venom: The Last Dance
# 1  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09            Terrifier 3
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 3  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 4  /qrwI2T844nrBUv3eDwQZRDdgSFs.jpg   2024-09-11       Transformers One
#
#    video  vote_average  vote_count
# 0  False         6.400         684
# 1  False         6.932         916
# 2  False         8.500        2758
# 3  False         7.301        1855
# 4  False         8.100         662

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MWJkOGVhZjJhNjU4MTUxZTdlZWUwOTdmOTY4ZTJjOCIsIm5iZiI6MTcyNzk3MDM0Mi41MDc4NTksInN1YiI6IjY2ZmViNWMxNzgzMGMxMzAxZTdjOTAwNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.tN9DHyONAM1fq4thObPuh4PqayuNkAUlOGro2ahq3Pg"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response['results'])
pop.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [878, 28, 12]   912649
# 1  False  /18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg    [27, 53, 9648]  1034541
# 2  False  /2fxnTXr8NwyTFkunkimJkGkhqfy.jpg      [18, 28, 27]  1118031
# 3  False  /dvBCdCohwWbsP5qAaglOXagDMtk.jpg     [28, 35, 878]   533535
# 4  False  /v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg  [16, 878, 10751]  1184918
#
#   original_language                       original_title  \
# 0                en                Venom: The Last Dance
# 1                en                          Terrifier 3
# 2                es  Apocalipsis Z: el principio del fin
# 3                en                 Deadpool & Wolverine
# 4                en                       The Wild Robot
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...    3685.151
# 1  Five years after surviving Art the Clown's Hal...    2813.154
# 2  When a kind of rabies that transforms people i...    2561.355
# 3  A listless Wade Wilson toils away in civilian ...    2060.103
# 4  After a shipwreck, an intelligent robot called...    2050.517
#
#                         poster_path release_date  \
# 0  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-22
# 1  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09
# 2  /wIGJnIFQlESkC2rLpfA8EDHqk4g.jpg   2024-10-04
# 3  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24
# 4  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12
#
#                                     title  video  vote_average  vote_count
# 0                   Venom: The Last Dance  False         6.401         682
# 1                             Terrifier 3  False         6.933         915
# 2  Apocalypse Z: The Beginning of the End  False         6.781         407
# 3                    Deadpool & Wolverine  False         7.700        5281
# 4                          The Wild Robot  False         8.487        2758

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MWJkOGVhZjJhNjU4MTUxZTdlZWUwOTdmOTY4ZTJjOCIsIm5iZiI6MTcyNzk3MDM0Mi41MDc4NTksInN1YiI6IjY2ZmViNWMxNzgzMGMxMzAxZTdjOTAwNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.tN9DHyONAM1fq4thObPuh4PqayuNkAUlOGro2ahq3Pg"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response['results'])
top.head() #need
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     250.071
# 1  Spanning the years 1945 to 1955, a chronicle o...     191.290
# 2  In the continuing saga of the Corleone crime f...     106.475
# 3  The true story of how businessman Oskar Schind...      78.333
# 4  The defense and the prosecution have rested an...      97.485
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
# 4  /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10              12 Angry Men
#
#    video  vote_average  vote_count
# 0  False         8.707       27094
# 1  False         8.690       20578
# 2  False         8.600       12412
# 3  False         8.565       15823
# 4  False         8.546        8625

# %%
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MWJkOGVhZjJhNjU4MTUxZTdlZWUwOTdmOTY4ZTJjOCIsIm5iZiI6MTcyNzk3MDM0Mi41MDc4NTksInN1YiI6IjY2ZmViNWMxNzgzMGMxMzAxZTdjOTAwNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.tN9DHyONAM1fq4thObPuh4PqayuNkAUlOGro2ahq3Pg"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response['results'])
up.head()
# Out:
#    adult                     backdrop_path                    genre_ids  \
# 0  False  /18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg               [27, 53, 9648]
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                [18, 27, 878]
# 2  False  /8mjYwWT50GkRrrRdyHzJorfEfcl.jpg                     [28, 12]
# 3  False  /rOmUuQEZfPXglwFs5ELLLUDKodL.jpg                 [28, 35, 14]
# 4  False  /llIXQAndg5kB6SWlp6ouUdO7Zxd.jpg  [28, 12, 18, 36, 10749, 53]
#
#         id original_language            original_title  \
# 0  1034541                en               Terrifier 3
# 1   933260                en             The Substance
# 2   558449                en              Gladiator II
# 3   845781                en                   Red One
# 4  1084736                fr  Le Comte de Monte-Cristo
#
#                                             overview  popularity  \
# 0  Five years after surviving Art the Clown's Hal...    2813.154
# 1  A fading celebrity decides to use a black mark...    1676.118
# 2  Years after witnessing the death of the revere...    1333.762
# 3  After Santa Claus (codename: Red One) is kidna...    1146.666
# 4  Edmond Dantes becomes the target of a sinister...     941.742
#
#                         poster_path release_date                      title  \
# 0  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09                Terrifier 3
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07              The Substance
# 2  /2cxhvwyEwRlysAmRH4iodkvo0z5.jpg   2024-11-13               Gladiator II
# 3  /cdqLnri3NEGcmfnqwk2TSIYtddg.jpg   2024-10-31                    Red One
# 4  /zw4kV7npGtaqvUxvJE9IdqdFsNc.jpg   2024-06-28  The Count of Monte-Cristo
#
#    video  vote_average  vote_count
# 0  False         6.900         916
# 1  False         7.301        1860
# 2  False         7.000         100
# 3  False         6.700          91
# 4  False         8.300         807

# %%
df = pd.concat([now, pop, top, up])

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    Returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df.head()
# Out:
#         id     budget    revenue
# 0   912649  120000000  394000000
# 1  1034541    2000000   78573405
# 2  1184918   78000000  292583746
# 3   933260   17500000   46818041
# 4   698687   75000000  124530200

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg         [878, 28, 12]   912649
# 1  False  /18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg        [27, 53, 9648]  1034541
# 2  False  /v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg      [16, 878, 10751]  1184918
# 3  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [18, 27, 878]   933260
# 4  False  /zViRwl3ySscZnbXZJ2Q9wq3SeUG.jpg  [16, 878, 12, 10751]   698687
#
#   original_language         original_title  \
# 0                en  Venom: The Last Dance
# 1                en            Terrifier 3
# 2                en         The Wild Robot
# 3                en          The Substance
# 4                en       Transformers One
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...    3685.151
# 1  Five years after surviving Art the Clown's Hal...    2813.154
# 2  After a shipwreck, an intelligent robot called...    2050.517
# 3  A fading celebrity decides to use a black mark...    1676.118
# 4  The untold origin story of Optimus Prime and M...    1468.358
#
#                         poster_path release_date                  title  \
# 0  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-22  Venom: The Last Dance
# 1  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09            Terrifier 3
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 3  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 4  /qrwI2T844nrBUv3eDwQZRDdgSFs.jpg   2024-09-11       Transformers One
#
#    video  vote_average  vote_count     budget    revenue
# 0  False         6.400         684  120000000  394000000
# 1  False         6.932         916    2000000   78573405
# 2  False         8.500        2758   78000000  292583746
# 3  False         7.301        1855   17500000   46818041
# 4  False         8.100         662   75000000  124530200

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <Axes: xlabel='budget', ylabel='revenue'>

# %%
import numpy as np
df["revenue_sqrt"] = np.sqrt(df["revenue"])
df["budget_sqrt"] = np.sqrt(df["budget"])

# %%
df.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg         [878, 28, 12]   912649
# 1  False  /18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg        [27, 53, 9648]  1034541
# 2  False  /v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg      [16, 878, 10751]  1184918
# 3  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [18, 27, 878]   933260
# 4  False  /zViRwl3ySscZnbXZJ2Q9wq3SeUG.jpg  [16, 878, 12, 10751]   698687
#
#   original_language         original_title  \
# 0                en  Venom: The Last Dance
# 1                en            Terrifier 3
# 2                en         The Wild Robot
# 3                en          The Substance
# 4                en       Transformers One
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...    3685.151
# 1  Five years after surviving Art the Clown's Hal...    2813.154
# 2  After a shipwreck, an intelligent robot called...    2050.517
# 3  A fading celebrity decides to use a black mark...    1676.118
# 4  The untold origin story of Optimus Prime and M...    1468.358
#
#                         poster_path release_date                  title  \
# 0  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-22  Venom: The Last Dance
# 1  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09            Terrifier 3
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 3  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 4  /qrwI2T844nrBUv3eDwQZRDdgSFs.jpg   2024-09-11       Transformers One
#
#    video  vote_average  vote_count     budget    revenue  revenue_sqrt  \
# 0  False         6.400         684  120000000  394000000  19849.433241
# 1  False         6.932         916    2000000   78573405   8864.164089
# 2  False         8.500        2758   78000000  292583746  17105.079538
# 3  False         7.301        1855   17500000   46818041   6842.371007
# 4  False         8.100         662   75000000  124530200  11159.310015
#
#     budget_sqrt
# 0  10954.451150
# 1   1414.213562
# 2   8831.760866
# 3   4183.300133
# 4   8660.254038

# %%
def get_best_fit(data, x, y):
    '''
    Determines the slope (m) and intercept (b) of the best fit line
    for two variables, x and y.
    '''
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)
    #1.26x + 1048

# %%
get_best_fit(df, 'revenue', 'budget')
# Out:
# 6021362505351522162
# 9023661065600555029
# -9028441724087595014
# 7205286357415726881
# 2384613088981865866
# -5043717455679626443
# 3367038797140801570
# 9170137773733598289
# -6081164599610787902
# -5493380175473253771
# -7513253027563350934
# 6305960917828472225
# -929226486716887526
# 7674672906219673045
# -4775829050780949294
# -1387244210299651311
# -606316646045984622
# -2433046358019949227
# -6867433346221545126
# 4537266463058779297
# -5112435077598079190
# 1076950179226982645
# 4658678159824413186
# 5632748864194212433
# 3999162292336380386
# -242081555749082955
# -7090982680062177590
# 1899202993106648097
# 8281731390047842490
# -6390141562948146027
# -5222927718462214222
# -6663371150203913711
# 7735272215536307122
# 1079514231339345045
# -8183901029085248326
# -1608229492027921375
# 2359784768801774282
# 3720141753403838645
# 2472841461778271714
# -1382116106074926511
# -7844730950155756030
# 1531741003245334773
# 8300555680418794282
# -5985030992344929119
# -4431530867626732198
# -5485688019136166571
# -9147502446873232238
# 3029769922871622417
# -5847359057320705838
# 1114598759968886229
# 5468899301030847002
# 7215542565865176481
# 6354528554471874666
# 2885857266850941557
# -3190471296997622846
# 6572286936635733073
# -4719356179668093918
# -171912498490000587
# 1767873906460461450
# 1100003035183292193
# -2175525112321508358
# -8058710536053940203
# 1897190837695548274
# -9201309138492146159
# -4460722317197920270
# -2327792772131325675
# -2802520503292362374
# -5884905510681030367
# 6871796279412221962
# -1425903280431708619
# 6115483957206281122
# -7397530155092912047
# -5071457469910184894
# -5353042060955089035
# -8242283928227624470
# 4707561001981760417
# -3396995417746037606
# 4337534960008084693
# -8982336012174975918
# -6463120186876116207
# -6551561637804887790
# 9199083708748260949
# 3895327705364226778
# -4016085574247438687
# C:\Users\hilo\AppData\Local\Temp\ipykernel_31416\3585185022.py:18: RuntimeWarning: overflow encountered in scalar add
#   res = res + temp
# 3911587943622816170
# -9215139888444111883
# -6502780923029119614
# -6398079233841758639
# -8901034820882028958
# 4435096389559621045
# -3283173749935911862
# 4837642908050475553
# -8095941783900319942
# -5190439678369195115
# -4892594849065701582
# -7202407295989839343
# 6326867054567943218
# -1198259944811457131
# 7115699853291062842
# -5624741698543600095
# (100, 0, -5624741698543600095)

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 5301194675.994258
# 4885054200.988514
# 9839375227.982773
# 20164157756.97703
# 35859401787.97128
# 56925107320.96552
# 83361274355.95981
# 115167902892.95401
# 152344992931.94827
# 194892544472.94254
# 242810557515.93677
# 296099032060.93115
# 354757968107.9253
# 418787365656.9196
# 488187224707.91394
# 562957545260.9082
# 643098327315.9022
# 728609570872.8966
# 819491275931.8909
# 915743442492.885
# 1017366070555.8796
# 1124359160120.8738
# 1236722711187.868
# 1354456723756.8618
# 1477561197827.8564
# 1606036133400.8506
# 1739881530475.8457
# 1879097389052.8386
# 2023683709131.8333
# 2173640490712.8276
# 2328967733795.822
# 2489665438380.816
# 2655733604467.8096
# 2827172232056.805
# 3003981321147.7993
# 3186160871740.7935
# 3373710883835.7866
# 3566631357432.7817
# 3764922292531.776
# 3968583689132.771
# 4177615547235.7646
# 4392017866840.7593
# 4611790647947.752
# 4836933890556.749
# 5067447594667.74
# 5303331760280.736
# 5544586387395.7295
# 5791211476012.726
# 6043207026131.722
# 6300573037752.712
# 6563309510875.706
# 6831416445500.702
# 7104893841627.695
# 7383741699256.69
# 7667960018387.685
# 7957548799020.68
# 8252508041155.674
# 8552837744792.665
# 8858537909931.66
# 9169608536572.654
# 9486049624715.648
# 9807861174360.645
# 10135043185507.639
# 10467595658156.63
# 10805518592307.629
# 11148811987960.623
# 11497475845115.615
# 11851510163772.607
# 12210914943931.604
# 12575690185592.598
# 12945835888755.594
# 13321352053420.59
# 13702238679587.578
# 14088495767256.572
# 14480123316427.572
# 14877121327100.566
# 15279489799275.557
# 15687228732952.549
# 16100338128131.541
# 16518817984812.535
# 16942668302995.531
# 17371889082680.525
# 17806480323867.52
# 18246442026556.516
# 18691774190747.508
# 19142476816440.508
# 19598549903635.504
# 20059993452332.492
# 20526807462531.492
# 20998991934232.484
# 21476546867435.47
# 21959472262140.473
# 22447768118347.465
# 22941434436056.46
# 23440471215267.453
# 23944878455980.445
# 24454656158195.44
# 24969804321912.438
# 25490322947131.438
# 26016212033852.426
# (100, 0, 26016212033852.426)

# %%
def CoeDet(df, x, y,m,b):
    y_mean = df[y].mean()
    Tsst = 0
    for value in df[y]:
        diff = (value - y_mean)
        squ = diff ** 2
        Tsst += squ

    Tssr = 0

    for i in range(len(df)):
        predicted = (m * df.loc[i][x]) + b
        diff = predicted - df.loc[i][y]
        squ = diff ** 2
        Tssr += squ 

    r2 = 1 - (Tssr / Tsst)
    return r2

# %%
CoeDet(df, "budget", "revenue", 1.26, 1048)
# Out:
# 0.029684120480797938

# %%
action = []
romance = []

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=2"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MWJkOGVhZjJhNjU4MTUxZTdlZWUwOTdmOTY4ZTJjOCIsIm5iZiI6MTcyNzk3MDM0Mi41MDc4NTksInN1YiI6IjY2ZmViNWMxNzgzMGMxMzAxZTdjOTAwNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.tN9DHyONAM1fq4thObPuh4PqayuNkAUlOGro2ahq3Pg"
}

response = requests.get(url, headers=headers)
response = response.json()["results"]
for i in range(len(response)):
    genres = response[i]["genre_ids"]
    if 28 in genres:
        action.append(response[i])
    if 10749 in genres:
        romance.append(response[i])
action = pd.DataFrame(action)
romance = pd.DataFrame(romance)

# %%
page = 2
while len(action) < 100 or len(romance) < 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=2" + str(page )
     
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3MWJkOGVhZjJhNjU4MTUxZTdlZWUwOTdmOTY4ZTJjOCIsIm5iZiI6MTcyNzk3MDM0Mi41MDc4NTksInN1YiI6IjY2ZmViNWMxNzgzMGMxMzAxZTdjOTAwNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.tN9DHyONAM1fq4thObPuh4PqayuNkAUlOGro2ahq3Pg"
    }
    page += 1
    response = requests.get(url, headers=headers)
    response = response.json()["results"]
    for i in range(len(response)):
        genres = response[i]["genre_ids"]
        temp = pd.DataFrame(response[i])
        if 28 in genres:
            action = pd.concat([temp, action], ignore_index=True)
        if 10749 in genres:
            romance = pd.concat([temp, romance], ignore_index=True)

# %%
print(len(action), len(romance))
action = action[:100]
romance = romance[:100]
# Out:
# 273 102

# %%
print(len(action), len(romance))
# Out:
# 100 100

# %%
action['vote_count'].max()
# Out:
# 20277

# %%
sns.scatterplot(data=action, x='vote_count', y='popularity')
# Out:
# <Axes: xlabel='vote_count', ylabel='popularity'>

# %%
action['popsqrt'] = np.sqrt(action['popularity'])

# %%
action['vote_countsqrt'] = np.sqrt(action['vote_count'])

# %%
sns.scatterplot(data=action, x='vote_countsqrt', y='popsqrt')
# Out:
# <Axes: xlabel='vote_countsqrt', ylabel='popsqrt'>
