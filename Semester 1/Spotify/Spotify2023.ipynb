# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('spotify2023.csv', encoding = 'latin1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
sns.histplot(df['in_apple_playlists'], bins=30)
# Out:
# <Axes: xlabel='in_apple_playlists', ylabel='Count'>

# %% [markdown]
# # Man I sure do LOVE copying code

# %%
summary = {
    'Max': df['in_apple_playlists'].max(),
    'Q3': df['in_apple_playlists'].quantile(0.75),
    'Median': df['in_apple_playlists'].median(),
    'Q1': df['in_apple_playlists'].quantile(0.25),
    'Min':df['in_apple_playlists'].min()
}
summary
# Out:
# {'Max': 672, 'Q3': 88.0, 'Median': 34.0, 'Q1': 13.0, 'Min': 0}

# %%
sns.boxplot(data=df, x= "in_apple_playlists")
# Out:
# <Axes: xlabel='in_apple_playlists'>

# %%
df_major = df[df['mode'] == 'Major']
df_minor = df[df['mode'] == 'Minor']

# %%
sns.histplot(data=df_major, x='in_apple_playlists', bins = 50, color = 'blue')
sns.histplot(data=df_minor, x='in_apple_playlists', bins = 50, color = 'red')
# Out:
# <Axes: xlabel='in_apple_playlists', ylabel='Count'>

# %%
sns.histplot(data=df, x='in_apple_playlists')
# Out:
# <Axes: xlabel='in_apple_playlists', ylabel='Count'>
